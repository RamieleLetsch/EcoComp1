# %%
"""
Programa: adulto
Descrição: este programa pergunta a idade de uma pessoa. Se a idade for maior do que 18 anos, o programa imprime na tela o texto "Oi! Você é um adulto.”
Data: 24/03/2026
Versão: 0.0.1

"""
# Out:
# '\nPrograma: adulto\nDescrição: este programa pergunta a idade de uma pessoa. Se a\nidade for maior do que 18 anos, o programa imprime na tela o\ntexto ”Oi! Você é um adulto.”\nData: 24/03/2026\nVersão: 0.0.1\n\n'

# %%
# Alocação de memória

idade = 0
texto = ""

# %%
# Entrada de dados

idade = int(input("\nQual a sua idade? "))
# Out:
# Qual a sua idade?  19

# %%
# Processamento de dados

if idade >= 18:
    texto = 'Oi! Você é um adulto.'

# %%
# Saída de dados

print(texto)
# Out:
# Oi! Você é um adulto.
